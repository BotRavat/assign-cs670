# %%
import matplotlib.pyplot as plt

queries = [1,5,10,20]
times = [565,913,1024,1516]   # ms

plt.plot(queries, times, marker='o')
plt.xlabel("Total Items (keeping item and query fixed)")
plt.ylabel("Time (ms)")
plt.title("Query Processing Time")
plt.grid(True)
plt.show()
